# %%
import numpy as np
 
# using loadtxt()
arr = np.loadtxt("test_2_speed_10_sec60.csv",
                 delimiter=",", dtype=str, usecols=(2,3,4,5,6), skiprows=16)

tracename = arr[0]

data = arr[12:]

data = data.astype(float)

display(tracename)
# Out:
# array(['I_bat [A]', 'I_dyno_LP [A]', 'i_motor_LP [A]',
#        'speed_motor [rads]', 'u_bat  [V]'], dtype='<U27')

# %%
import matplotlib.pyplot as plt

plt.plot(data)
plt.show()

# %%
class dSpace_Datahandler()
